# %% [markdown]
# ## Realizando Imports

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import yfinance as yf
import lxml

# %% [markdown]
# ## Lendo dados financeiros das empresas

# %%
url = 'https://fundamentus.com.br/resultado.php'
agent = {"User-Agent": "Mozzila/5.0"}
response = requests.get(url, headers=agent)
soup = BeautifulSoup(response.text, 'html.parser')
table =soup.find_all('table')[0]
df = pd.read_html(str(table), decimal=',', thousands='.')[0]
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
df.head()
# Out:
#    Papel    Cotação    P/L   P/VP    PSR Div.Yield  P/Ativo  P/Cap.Giro  \
# 0  CSTB4   147.6900 0.0000 0.0000 0.0000     0,00%   0.0000      0.0000
# 1  MNSA4     0.4700 0.0000 0.0000 0.0000     0,00%   0.0000      0.0000
# 2  IVTT3     0.0000 0.0000 0.0000 0.0000     0,00%   0.0000      0.0000
# 3  PORP4     2.4000 0.0000 0.0000 0.0000     0,00%   0.0000      0.0000
# 4  CFLU4 1,000.0000 0.0000 0.0000 0.0000     0,00%   0.0000      0.0000
#
#    P/EBIT  P/Ativ Circ.Liq  ...  EV/EBITDA  Mrg Ebit Mrg. Líq. Liq. Corr.  \
# 0  0.0000           0.0000  ...     0.0000    40,85%    28,98%     2.6000
# 1  0.0000           0.0000  ...     0.0000  -208,15%  -362,66%     3.6300
# 2  0.0000           0.0000  ...     0.0000     0,00%     0,00%     0.0000
# 3  0.0000           0.0000  ...     0.0000     0,00%     0,00%     0.0000
# 4  0.0000           0.0000  ...     0.0000     8,88%    10,72%     1.1000
#
#       ROIC      ROE Liq.2meses        Patrim. Líq  Dív.Brut/ Patrim.  \
# 0   22,40%   20,11%     0.0000 8,420,670,000.0000             0.1400
# 1  -13,50%  145,70%     0.0000    -9,105,000.0000            -6.5200
# 2    0,00%   -0,40%     0.0000 1,083,050,000.0000             0.0000
# 3    0,00%   -2,08%     0.0000    22,399,000.0000             0.0000
# 4   17,68%   32,15%     0.0000    60,351,000.0000             0.0600
#
#    Cresc. Rec.5a
# 0         31,91%
# 1        -41,11%
# 2         20,67%
# 3         13,66%
# 4          8,14%
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (979, 21)

# %%
df.dtypes
# Out:
# Papel                 object
# Cotação              float64
# P/L                  float64
# P/VP                 float64
# PSR                  float64
# Div.Yield             object
# P/Ativo              float64
# P/Cap.Giro           float64
# P/EBIT               float64
# P/Ativ Circ.Liq      float64
# EV/EBIT              float64
# EV/EBITDA            float64
# Mrg Ebit              object
# Mrg. Líq.             object
# Liq. Corr.           float64
# ROIC                  object
# ROE                   object
# Liq.2meses           float64
# Patrim. Líq          float64
# Dív.Brut/ Patrim.    float64
# Cresc. Rec.5a         object
# dtype: object

# %% [markdown]
# # Limpando dataset

# %% [markdown]
# ## Convertendo string com % em float
# * Div.Yield
# * Mrg Ebit
# * Mrg. Líq.
# * ROIC
# * ROE
# * Cresc. Rec.5a

# %%
df['Div.Yield'] = df['Div.Yield'].str.replace(',', '.')
df['Div.Yield'] = df['Div.Yield'].str.rstrip('%').astype('float') / 100.0

df['Mrg Ebit'] = df['Mrg Ebit'].str.replace('.', '')
df['Mrg Ebit'] = df['Mrg Ebit'].str.replace(',', '.')
df['Mrg Ebit'] = df['Mrg Ebit'].str.rstrip('%').astype('float') / 100.0

df['Mrg. Líq.'] = df['Mrg. Líq.'].str.replace('.', '')
df['Mrg. Líq.'] = df['Mrg. Líq.'].str.replace(',', '.')
df['Mrg. Líq.'] = df['Mrg. Líq.'].str.rstrip('%').astype('float') / 100.0

df['ROIC'] = df['ROIC'].str.replace('.', '')
df['ROIC'] = df['ROIC'].str.replace(',', '.')
df['ROIC'] = df['ROIC'].str.rstrip('%').astype('float') / 100.0

df['ROE'] = df['ROE'].str.replace('.', '')
df['ROE'] = df['ROE'].str.replace(',', '.')
df['ROE'] = df['ROE'].str.rstrip('%').astype('float') / 100.0


df['Cresc. Rec.5a'] = df['Cresc. Rec.5a'].str.replace('.', '')
df['Cresc. Rec.5a'] = df['Cresc. Rec.5a'].str.replace(',', '.')
df['Cresc. Rec.5a'] = df['Cresc. Rec.5a'].str.rstrip('%').astype('float') / 100.0


df.head(15)
# Out:
# C:\Users\bruno_snsmfhf\AppData\Local\Temp/ipykernel_16576/3262658232.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Mrg Ebit'] = df['Mrg Ebit'].str.replace('.', '')
# C:\Users\bruno_snsmfhf\AppData\Local\Temp/ipykernel_16576/3262658232.py:8: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Mrg. Líq.'] = df['Mrg. Líq.'].str.replace('.', '')
# C:\Users\bruno_snsmfhf\AppData\Local\Temp/ipykernel_16576/3262658232.py:12: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['ROIC'] = df['ROIC'].str.replace('.', '')
# C:\Users\bruno_snsmfhf\AppData\Local\Temp/ipykernel_16576/3262658232.py:16: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['ROE'] = df['ROE'].str.replace('.', '')
# C:\Users\bruno_snsmfhf\AppData\Local\Temp/ipykernel_16576/3262658232.py:21: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Cresc. Rec.5a'] = df['Cresc. Rec.5a'].str.replace('.', '')
#     Papel    Cotação       P/L      P/VP     PSR  Div.Yield  P/Ativo  \
# 0   CSTB4   147.6900    0.0000    0.0000  0.0000     0.0000   0.0000
# 1   MNSA4     0.4700    0.0000    0.0000  0.0000     0.0000   0.0000
# 2   IVTT3     0.0000    0.0000    0.0000  0.0000     0.0000   0.0000
# 3   PORP4     2.4000    0.0000    0.0000  0.0000     0.0000   0.0000
# 4   CFLU4 1,000.0000    0.0000    0.0000  0.0000     0.0000   0.0000
# 5   CLAN3     0.0000    0.0000    0.0000  0.0000     0.0000   0.0000
# 6   PMET3     0.0000    0.0000    0.0000  0.0000     0.0000   0.0000
# 7   CSTB3   150.0000    0.0000    0.0000  0.0000     0.0000   0.0000
# 8   MNSA3     0.4200    0.0000    0.0000  0.0000     0.0000   0.0000
# 9   POPR4    10.1700    0.0000    0.0000  0.0000     0.0000   0.0000
# 10  GFSA3     2.7300 -640.1900    0.5600  0.7960     0.0000   0.2270
# 11  PLDN4   486.0000 -553.0700    1.0800  0.9190     0.0000   0.6110
# 12  DASA3    43.1300 -391.2800    3.2500  2.5470     0.0058   1.3300
# 13  LCSA4    35.0900 -337.5200 -228.0000 79.7380     0.0000 125.3080
# 14  MAPT4    37.9500 -317.0600   -5.9400  0.0000     0.0000  45.1180
#
#     P/Cap.Giro    P/EBIT  P/Ativ Circ.Liq  ...  EV/EBITDA  Mrg Ebit  \
# 0       0.0000    0.0000           0.0000  ...     0.0000    0.4085
# 1       0.0000    0.0000           0.0000  ...     0.0000   -2.0815
# 2       0.0000    0.0000           0.0000  ...     0.0000    0.0000
# 3       0.0000    0.0000           0.0000  ...     0.0000    0.0000
# 4       0.0000    0.0000           0.0000  ...     0.0000    0.0888
# 5       0.0000    0.0000           0.0000  ...     0.0000    0.0000
# 6       0.0000    0.0000           0.0000  ...     0.0000    0.0000
# 7       0.0000    0.0000           0.0000  ...     0.0000    0.4085
# 8       0.0000    0.0000           0.0000  ...     0.0000   -2.0815
# 9       0.0000    0.0000           0.0000  ...     0.0000    0.0866
# 10      0.7700    9.8900           2.6100  ...    16.0500    0.0804
# 11      1.0700  -75.5600           3.1000  ...   -33.1200   -0.0122
# 12      8.2100  572.8100          -8.1200  ...    28.9900    0.0044
# 13   -202.2700 -505.8000         -96.6100  ...  -506.5600   -0.1577
# 14 -3,170.5500 -371.0200          -5.2500  ...  -371.0200    0.0000
#
#     Mrg. Líq.  Liq. Corr.    ROIC     ROE      Liq.2meses        Patrim. Líq  \
# 0      0.2898      2.6000  0.2240  0.2011          0.0000 8,420,670,000.0000
# 1     -3.6266      3.6300 -0.1350  1.4570          0.0000    -9,105,000.0000
# 2      0.0000      0.0000  0.0000 -0.0040          0.0000 1,083,050,000.0000
# 3      0.0000      0.0000  0.0000 -0.0208          0.0000    22,399,000.0000
# 4      0.1072      1.1000  0.1768  0.3215          0.0000    60,351,000.0000
# 5      0.0000      0.0000  0.0000 -0.0105          0.0000 1,012,240,000.0000
# 6      0.0000      0.0000  0.0000  0.0410          0.0000  -290,863,000.0000
# 7      0.2898      2.6000  0.2240  0.2011          0.0000 8,420,670,000.0000
# 8     -3.6266      3.6300 -0.1350  1.4570          0.0000    -9,105,000.0000
# 9      0.0565      1.0800  0.1525  0.1993          0.0000   545,803,000.0000
# 10    -0.0010      1.7500  0.0265 -0.0009 19,652,600.0000 1,630,560,000.0000
# 11    -0.0017     10.8100 -0.0127 -0.0020          0.0000   289,939,000.0000
# 12    -0.0056      1.6100  0.0033 -0.0083  8,832,160.0000 7,265,200,000.0000
# 13    -0.2363      0.2900 -0.2874  0.6755          0.0000  -377,568,000.0000
# 14     0.0000      0.0000 -0.1234  0.0187        175.4700    -5,876,000.0000
#
#     Dív.Brut/ Patrim.  Cresc. Rec.5a
# 0              0.1400         0.3191
# 1             -6.5200        -0.4111
# 2              0.0000         0.2067
# 3              0.0000         0.1366
# 4              0.0600         0.0814
# 5              0.0000        -0.6396
# 6              0.0000         0.3774
# 7              0.1400         0.3191
# 8             -6.5200        -0.4111
# 9              0.8200         0.3093
# 10             0.7800         0.1880
# 11             0.0100         0.1026
# 12             0.7900         0.2754
# 13            -0.3500        63.5407
# 14             0.0000         0.0000
#
# [15 rows x 21 columns]
